# %% [markdown]
# <a href="https://colab.research.google.com/github/nfmanios-debug/Programacion_para_Ciencia_de_Datos-/blob/main/Taller_pcd_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nelson Fabián Manios Ascencio
#
# ![LinkedIn Profile Picture](https://img.icons8.com/color/144/000000/linkedin.png)
#
# ### 📍 Senior Data Engineer | PySpark | Databricks | Lakehouse
# *   **Ubicación:** Bogotá, Colombia
# *   **Contacto:** +57 317 699 0391 | nfmanios@gmail.com
# *   **Idiomas:** Español (Nativo), Inglés (B2+ profesional)
# *   **LinkedIn:** [Ver Perfil](https://www.linkedin.com/in/nelson-fabian-manios-ascencio-1289b316a/)
# *   **GitHub:** [Mis Proyectos](https://github.com/nfmanios-debug)
#
# ---
#
# ## 👤 Perfil Profesional
# Ingeniero de Datos Senior con más de 8 años de experiencia en datos, BI y analítica. Experto en construir pipelines escalables y gestionar despliegues como código.
#
# > "La ingeniería de datos no se trata solo de mover bits, sino de construir los cimientos sobre los cuales se toman las decisiones del futuro."
#
# ### 🛠️ Resumen de Tecnologías Principales
# | Categoría | Herramientas Clave |
# | :--- | :--- |
# | Big Data | PySpark, Spark SQL, Delta Lake |
# | Cloud | Azure Databricks, ADF, Synapse |
# | DevOps | DABs, CI/CD, Git, YAML |
# | Bases de Datos | SQL Server, Oracle, ADLS Gen2 |
#
# ## ✅ Habilidades Clave
# *   Arquitectura Medallion (Bronze, Silver, Gold).
# *   Implementación de **Spark Declarative Pipelines (SDP)**.
# *   Optimización de procesamiento distribuido.

# %% [markdown]
# ## 💼 Experiencia Profesional
#
# ### Senior Data Engineer | Aspen View / Scotiabank
# *Diciembre 2025 – Junio 2026*
# *   Diseño y optimización de pipelines financieros con **PySpark** y Delta Lake.
# *   Estructuración de jobs como código mediante con configuración YAML y targets por ambiente.
# *   Implementación de pipelines declarativos con **SDP/Lakeflow** y controles de calidad.
#
# ### Senior Cloud Data Engineer - Azure | AXA Colpatria
# *Marzo 2025 – Agosto 2025*
# *   Liderazgo en la migración de procesos ETL desde IBM DataStage hacia pipelines cloud-native en Databricks.
# *   Construcción de capas **Bronze, Silver y Gold** aplicando limpieza y reglas de calidad.
# *   Estandarización de dependencias y transformaciones usando DABs y SDP.
#
# ### Senior Azure Data Engineer | Bluetab / Credicorp Capital
# *Marzo 2023 – Febrero 2025*
# *   Diseño de pipelines desde Oracle y APIs mediante ADF y Databricks.
# *   Construcción de **Data Lake financiero** con conceptos de Data Vault.
# *   Implementación de CI/CD con Azure DevOps para versionamiento de jobs.
#
# ### Data Engineer | NTT DATA / Ecopetrol
# *Enero 2022 – Diciembre 2022*
# *   Desarrollo de procesos ETL/ELT e integración de APIs y bases de datos Oracle.
# *   Virtualización de datos con Denodo y automatización con Logic Apps.
#
# ### Experiencia Previa
# *   **Compensar:** Administrador Data Warehouse (Informatica PowerCenter, SQL Server).
# *   **Despegar:** BI Operations Management Analyst (AWS Data Lake, Presto, PySpark).
# *   **Claro:** Analista de Gestión Comercial (SQL, VBA, Modelado Estadístico).

# %% [markdown]
# ## 🎓 Formación y Certificaciones
#
# ### Educación (Orden Cronológico)
# 1. **Especialización en Machine Learning** | Universidad EAN (*En curso*)
# 2. **Especialización en Desarrollo de Bases de Datos** | Universidad Jorge Tadeo Lozano (*2022*)
# 3. **Administración de Empresas** | Politécnico Grancolombiano (*2018*)
#
# ### Certificaciones Destacadas
# *   **Microsoft Certified:** Azure Data Engineer Associate (DP-203).
# *   **Microsoft Certified:** Azure Data Fundamentals (DP-900).
# *   **Databricks:** Fundamentals Accreditation & Generative AI Fundamentals.
