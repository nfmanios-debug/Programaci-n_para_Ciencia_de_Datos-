# %% [markdown]
# <a href="https://colab.research.google.com/github/nfmanios-debug/Programaci-n_para_Ciencia_de_Datos-/blob/main/Copia_de_taller02_programas_b_sicos_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Taller 2](https://github.com/luiscobo/poo/blob/main/banner-taller2.jpg?raw=true)

# %% [markdown]
# ---
#
# ## Ejercicio en clase
#
# Escribir un programa que pregunte al usuario por el número de horas trabajadas y el salario por hora. Después debe mostrar por pantalla la paga que le corresponde.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
# Definición Variables
horas = int(input("Introduzca el numero de horas trabajadas: "))
costo = float(input("Introduzca el salario por hora: "))

# Calculo
pago = horas * costo

# Resultado
print(f"el pago que corresponde es: {pag}")
# Out:
# Introduzca el número de horas trabajadas: 10
# Introduzca el salario por hora: 10
# La paga que le corresponde es: 100.0

# %% [markdown]
# ---
#
# ## Ejercicio en clase
#
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
# Definición Constantes
g_payaso = 112
g_muñeca = 75

# Definición Variables

n_payasos = int(input("Introduzca el número de payasos vendidos: "))
n_muñecas = int(input("Introduzca el número de muñecas vendidas: "))

# Calculo

peso_total = (n_payasos * g_payaso) + (n_muñecas * g_muñeca)

# Resultado

print(f"El peso total del paquete es: {peso_total} g")
# Out:
# Introduzca el número de payasos vendidos: 100
# Introduzca el número de muñecas vendidas: 50
# El peso total del paquete es: 14950 g

# %% [markdown]
# ---
#
# ## Ejercicio 1
# Escriba un programa en Python que obtenga la solución a la ecuación de primer $ax+b=0$. Realice primero el **modelaje del problema** y luego el programa en Python.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %% [markdown]
# #### Algoritmo
# 1. Leer los datos de entrada
# 2. Calcular los datos de salida
# 3. Mostrar los datos de salida

# %%
# Definición Variables
a = float(input("Introduzca el valor de a, diferente a 0: "))
b = float(input("Introduzca el valor de b, diferente a 0 : "))

# Calculo
x = -b / a

# Resultado

print(f" la solucion de la ecuacion {a}x + {b} = 0 es x = : {x} ")
# Out:
# Introduzca el valor de a diferente a 0: 5
# Introduzca el valor de b diferente a 0 : 42424
#  la solucion de la ecuacion 5.0x + 42424.0 = 0 es x = : -8484.8

# %% [markdown]
# ---
# ## Ejercicio 2
#
# De acuerdo a la ley de gravitación universal de Newton, un cuerpo con una masa de $m_1$ atrae a otro cuerpo con una masa $m_2$ con una cantidad de fuerza $F$ acuerdo a la siguiente fórmula:
#
# ![Ejericio 2](https://latex.codecogs.com/png.latex?%5Cdpi%7B200%7D%20%5Cbg_white%20%5Clarge%20F%20%3D%20%5Cfrac%7BGm_1m_2%7D%7Br%5E2%7D)
#
# donde $r$ es la distancia entre los dos cuerpos y $G$ es la constante universal ($G = 6.674 \times 10^{-11}$). Escriba el modelaje y el algoritmo, así como el programa en Python que halle la fuerza de atracción de dos cuerpos con masas $m_1$ Y $m_2$, separados una distancia de $r$.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %% [markdown]
# #### Algoritmo
# 1. Leer los datos de entrada
# 2. Calcular los datos de salida
# 3. Mostrar los datos de salida

# %%
# Definicion Constante
G = 6.674e-11

# Definicion Variable
m1 = float(input("Introduzca la masa del primer cuerpo (kg): "))
m2 = float(input("Introduzca la masa del segundo cuerpo (kg): "))
r = float(input("Introduzca la distancia entre los cuerpos (m): "))

# Cálculo
fuerza = (G * m1 * m2) / (r**2)

#Resultado
print(f"La fuerza de atracción es: {fuerza} N")
# Out:
# Introduzca la masa del primer cuerpo (kg): 70
# Introduzca la masa del segundo cuerpo (kg): 100
# Introduzca la distancia entre los cuerpos (m): 2000
# La fuerza de atracción es: 1.1679499999999998e-13 N

# %% [markdown]
# ## Ejercicio 3
# Una tienda vende manzanas y peras. Si se sabe el número de peras y el número de manzanas que se vendieron en un día determinado, así como el precio de una manzana y el precio de una pera, determine cuánto dinero obtuvo la tienda por la venta de todas las manzanas y las peras.
#
# Realice el modelaje y programa en Python que resuelva el problema anterior.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
# Definicion Variable
mc  = int(input("Introduzca la cantidad de manzanas vendidas: "))
mp  = float(input("Introduzca el precio de las manzana: "))
pc  = int(input("Introduzca la cantidad de peras vendidas: "))
pp  = float(input("Introduzca el precio de las peras: "))

# Cálculo
dinero = int((mc * mp) + (pc * pp))

#Resultado
print(f"total de venta manzanas y peras : ${dinero}")
# Out:
# Introduzca la cantidad de manzanas vendidas: 5
# Introduzca el precio de las manzana: 100
# Introduzca la cantidad de peras vendidas: 7
# Introduzca el precio de las peras: 200
# total de venta manzanas y peras : $1900

# %% [markdown]
# ---
# ## Ejercicio 4
# Una empresa constructora vende terrenos con la forma de la figura a continuación:
#
# ![Ejercicio2](https://bit.ly/EAN190201)
#
# Realice el modelaje, algoritmo y el programa en Python que permita obtener el área respectiva del terreno.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
# Lado A | `A` | float
# Lado B | `B` | float
# Lado C | `C` | float
#
# _Datos Intermedios:_
#
# Nombre | Identificador | Tipo
# ---|---|---
# Área del triángulo superior | `ATriangulo` | `float`
# Área del rectángulo inferior | `ARectangulo` | `float`
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---
# Área del Terreno | `ATerreno` | `float`

# %% [markdown]
# #### Pseudo-código
#
# 1. Leer los datos de entrada
# 2. Calcular los datos de salida
# 3. Mostrar los datos de salida

# %%
# Definicion Variables
A = float(input("Ingrese la medida del lado A altura mayor: "))
B = float(input("Ingrese la medida del lado B base: "))
C = float(input("Ingrese la medida del lado C altura menor: "))

# Cálculo
ATriangulo = (B * (A - C)) / 2
ARectangulo = B * C
ATerreno = ATriangulo + ARectangulo

#Resultado
print(f"Área del triángulo superior: {ATriangulo:}")
print(f"Área del rectángulo inferior: {ARectangulo}")
print(f"Área total del terreno: {ATerreno}")
# Out:
# Ingrese la medida del lado A altura mayor: 5
# Ingrese la medida del lado B base: 10
# Ingrese la medida del lado C altura menor: 5
# Área del triángulo superior: 0.0
# Área del rectángulo inferior: 50.0
# Área total del terreno: 50.0

# %% [markdown]
# ## Ejercicio 5
#
# Escriba el modelaje y el programa en Python que permita calcular el área y el perímetro de un trapecio, de acuerdo a lo que se presenta en la siguiente gráfica:
#
# <img src="https://www.neurochispas.com/wp-content/uploads/2022/07/Formulas-del-perimetro-y-del-area-de-un-Trapecio.png" width="50%">

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
# Definicion Variables
a = float(input("Ingrese la medida del lado 'a': "))
b = float(input("Ingrese la medida de la base menor 'b': "))
c = float(input("Ingrese la medida del lado 'c': "))
d = float(input("Ingrese la medida de la base mayor 'd': "))
h = float(input("Ingrese la medida de la altura 'h': "))

# Cálculo
p = a + b + c + d
A = (h / 2) * (b + d)

#Resultado
print(f"Perímetro (p): {p}")
print(f"Área (A): {A}")
# Out:
# Ingrese la medida del lado 'a&c': 10
# Ingrese la medida de la base menor 'b&d': 20
# Ingrese la medida de la altura 'h': 30
# Perímetro (p): 30.0
# Área (A): 300.0

# %% [markdown]
# ## Ejercicio 5
#
# Escriba el modelaje y un programa en Python que permita obtener el área lateral ($A_L$), el área total ($A_T$) y el volumen de un cono, a partir del valor de la generatriz ($g$), el radio de la base ($r$) y la altura ($h$) del cono. Las fórmulas se presentan en la siguiente figura:
#
# ![Un cono](https://cuerpossolidosgeometricos1.wordpress.com/wp-content/uploads/2012/03/areacono1.jpg)

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
import math

# Definicion Variables
g = float(input("Ingrese el valor de la generatriz (g): "))
r = float(input("Ingrese el valor del radio de la base (r): "))
h = float(input("Ingrese el valor de la altura (h): "))

# Cálculo
AL = math.pi * r * g
AT = AL + math.pi * (r ** 2)
V = (1 / 3) * math.pi * (r ** 2) * h

#Resultado
print(f"Área Lateral AL: {AL}")
print(f"Área Total AT:   {AT}")
print(f"Volumen V:      {V}")
# Out:
# Ingrese el valor de la generatriz (g): 10
# Ingrese el valor del radio de la base (r): 10
# Ingrese el valor de la altura (h): 10
# Área Lateral (AL): 314.1592653589793
# Área Total (AT):   628.3185307179587
# Volumen (V):      1047.1975511965977

# %% [markdown]
# ---
# ## Ejercicio 6
# Se requiere obtener el área de la siguiente figura geométrica con forma de cono de helado.
#
# ![Ejercicio 6](https://bit.ly/2mq10Tp)
#
# Para resolver este problema se puede partir de que está formada por tres figuras: dos triángulos rectángulos, con `H` como hipotenusa y `R` como como uno de los catetos, que también es el radio de la otra figura, una semicircunferencia que forma la parte circular del cono de helado.
#
# Escriba el modelaje, y el programa en Python que resuelve el problem en cuestión.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
import math

# Definicion Variables
H = float(input("Ingrese el valor de la hipotenusa (H): "))
R = float(input("Ingrese el valor del radio (R): "))

# Cálculo
C = math.sqrt(H**2 - R**2)
ATriangulos = R * C
ASemicirculo = (math.pi * (R**2)) / 2
ATotal = ATriangulos + ASemicirculo

#Resultado
print(f"Cateto faltante (C): {C}")
print(f"Área total del cono de helado: {ATotal}")
# Out:
# Ingrese el valor de la hipotenusa (H): 10
# Ingrese el valor del radio (R): 5
# Cateto faltante (C): 8.660254037844387
# Área total del cono de helado: 82.57117835909435

# %% [markdown]
# ---
# ## Ejercicio 7
# Un productor de leche lleva el registro de lo que produce en litros, pero cuando vende la leche le pagan en galones. Realice el modelaje y el programa en Python correspondiente, que ayude al productor a saber cuánto recibirá por la entrega de su producción de leche de un día. Tenga en cuenta que 1 galón = 3.785 litros.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
# Definicion Variables
L = float(input("Ingrese la cantidad de litros producidos en el día: "))
PG = float(input("Ingrese el precio por galón: "))

# Cálculo
galones = L / 3.785
GA = galones * PG

#Resultado
print(f"Total de galones producidos: {galones} gal")
print(f"Monto total a recibir: ${GA}")
# Out:
# Ingrese la cantidad de litros producidos en el día: 1000
# Ingrese el precio por galón: 5
# Total de galones producidos: 264.2007926023778 gal
# Monto total a recibir: $1321.003963011889

# %% [markdown]
# ---
# ## Ejercicio 8
#
# La Empresa de acueducto requiere determinar el pago que debe realizar una persona por el total de metros cúbicos de agua que consume al llenar una piscina con las dimensiones presentadas en la figura a continuación.
#
# ![Ejercicio 6](https://bit.ly/2nguL9c)
#
# Donde  `A` se refiere a la altura de la piscina, `L` se refiere al largo de la piscina y `N` se refiere al ancho de la piscina. Y el número de metros que tiene la piscina se obtiene multiplicando el ancho por el largo por la altura de la piscina. Tenga en cuenta también que la empresa de acueducto cobra un valor dado por cada metro cúbico consumido.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
# Definicion Variables
A = float(input("Ingrese la altura de la piscina (A) en metros: "))
L = float(input("Ingrese el largo de la piscina (L) en metros: "))
N = float(input("Ingrese el ancho de la piscina (N) en metros: "))
CM = float(input("Ingrese el costo por cada metro cúbico ($): "))

# Cálculo
V = A * L * N
P = V * CM

#Resultado
print(f"Volumen de la piscina: {V} m3")
print(f"Total a pagar: ${P}")
# Out:
# Ingrese la altura de la piscina (A) en metros: 2
# Ingrese el largo de la piscina (L) en metros: 100
# Ingrese el ancho de la piscina (N) en metros: 50
# Ingrese el costo por cada metro cúbico ($): 235
# Volumen de la piscina: 10000.0 m³
# Total a pagar: $2350000.0

# %% [markdown]
# ---
#
# ### Ejercicio 9
#
# Suponga que un inversionista invierte una cierta cantidad de dinero (llamémosla $C$) a una tasa de interés (llamémosla $i$) durante una cierta cantidad de años ($n$). Construya el modelaje y el programa en Python que permita obtener el valor presente de esa cantidad de dinero invertido a la tasa de interés durante esos años. La fórmula para encontrar ese valor presente (llamémoslo $VP$) es la siguiente:
#
# $$
# VP=\frac{C}{(1+i)^n}
# $$

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
# Definicion Variables
C = float(input("Ingrese la cantidad de dinero invertido / capital (C): "))
interes_porcentaje = float(input("Ingrese la tasa de interés anual (%): "))
n = int(input("Ingrese el numero de años (n): "))

# Cálculo
i = interes_porcentaje / 100
VP = C / ((1 + i) ** n)

#Resultado
print(f"El Valor Presente (VP) de la inversión es: ${VP}")
# Out:
# Ingrese la cantidad de dinero invertido / capital (C): 1000000
# Ingrese la tasa de interés anual (%): 1.1
# Ingrese el numero de años (n): 72
# El Valor Presente (VP) de la inversión es: $454900.9014517094

# %% [markdown]
# ---
# ## Ejercicio 10
#
# Todo punto del eje cartesiano está descrito por dos elementos: su coordenada $x$ (o «abscisa») y su coordenada $y$ (que también se llama la «ordenada»). Suponga que tenemos las coordenadas $x$ y $y$ de dos puntos: $x_1$ y $y_1$ para el primer punto, y también $x_2$ y $y_2$ para el segundo punto. Queremos encontrar la distancia entre esos dos puntos, pero también la pendiente de la recta que une esos dos puntos, y finalmente, las coordenadas del punto medio entre esos dos puntos.
#
# ![Dos punto](https://i2.wp.com/www.celeberrima.com/wp-content/uploads/2018/11/Distancia-entre-dos-puntos-geometr%C3%ADa-anal%C3%ADtica-%E2%80%93-F%C3%B3rmula-y-ejemplos.jpg?resize=768%2C551&ssl=1)
#
# La distancia se obtiene con la siguiente fórmula:
#
# $$
# d = \sqrt{(y_2-y_1)^2 + (x_2-x_1)^2}
# $$
#
# La pendiente ($m$) de la recta que une los dos puntos se halla a partir de la siguiente fórmula:
#
# $$
# m = \frac{y_2-y_1}{x_2-x_1}
# $$
#
# Y las coordenadas del punto medio se obtienen con las siguientes fórmulas:
# $$
# x_m = \frac{x_1+x_2}{2}
# $$
#
# $$
# y_m = \frac{y_1+y_2}{2}
# $$
#
# Escriba el modelaje y el programa en Python que permita obtener todos los datos solicitados a partir de las 4 coordenadas.

# %% [markdown]
# #### Modelaje
#
# _Datos de Entrada:_
#
# Nombre | Identificador | Tipo
# ---|---|---
#
#
# _Datos de Salida:_
#
# Nombre | Identificador | Tipo
# ---|---|---

# %%
import math

# Definicion Variables
x1 = float(input("Ingrese la coordenada x1:"))
y1 = float(input("Ingrese la coordenada y1:"))
x2 = float(input("Ingrese la coordenada x2:"))
y2 = float(input("Ingrese la coordenada y2:"))

# Cálculo
d = math.sqrt((y2 - y1)**2 + (x2 - x1)**2)
m = (y2 - y1) / (x2 - x1)
xm = (x1 + x2) / 2
ym = (y1 + y2) / 2

#Resultado
print(f"Distancia (d): {d}")
print(f"Pendiente (m): {m}")
print(f"Punto Medio (xm, ym): ({xm}, {ym})")
# Out:
# Ingrese la coordenada x1: 1
# Ingrese la coordenada y1: 2
# Ingrese la coordenada x2: 3
# Ingrese la coordenada y2: 4
# Distancia (d): 2.8284271247461903
# Pendiente (m): 1.0
# Punto Medio (xm, ym): (2.0, 3.0)

# %% [markdown]
# ---

# %% [markdown]
# ### Ejercicio 11
#
# Realice el modelaje y el programa en Python que resuelva el siguiente problema:
#
# > Tres personas deciden invertir su dinero para fundar una empresa. Cada una de ellas
# > invierte una cantidad distinta. Obtener el porcentaje que cada cual invierte con
# > respecto a la cantidad total invertida.
#
# ### Modelaje
#
# **Datos de Entrada:**
#
# Nombre | Identificador | Tipo
# ---|---|---
# dinero invertido primera persona|m|float
# dinero invertido segunda persona|n|float
# dinero invertido tercera persona|o|float
#
#
# **Datos de Salida:**
#
# Nombre | Identificador | Tipo
# ---|---|---
# porcentaje invertido primera persona | p1 |float
# porcentaje invertido segunda persona | p2|float
# porcentaje invertido tercera persona | p3 |float

# %%
# Escribir aquí la solución al ejercicio 11

# Definicion Variables
m = float(input("Ingrese el dinero invertido por la primera persona (m): "))
n = float(input("Ingrese el dinero invertido por la segunda persona (n): "))
o = float(input("Ingrese el dinero invertido por la tercera persona (o): "))

# Cálculo
total = m + n + o
p1 = (m / total) * 100
p2 = (n / total) * 100
p3 = (o / total) * 100

#Resultado
print(f"Porcentaje de la primera persona (p1): {p1}%")
print(f"Porcentaje de la segunda persona (p2): {p2}%")
print(f"Porcentaje de la tercera persona (p3): {p3}%")
# Out:
# Ingrese el dinero invertido por la primera persona (m): 5000
# Ingrese el dinero invertido por la segunda persona (n): 100
# Ingrese el dinero invertido por la tercera persona (o): 4044000
# Porcentaje de la primera persona (p1): 0.12348423106369316%
# Porcentaje de la segunda persona (p2): 0.0024696846212738633%
# Porcentaje de la tercera persona (p3): 99.87404608431504%
