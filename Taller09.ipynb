# %% [markdown]
# # **Taller 09 - Agregar columnas con *pandas***
# ---
# <img src = "https://pandas.pydata.org/static/img/pandas.svg" alt = "pandas Logo" width = "70%">  </img>
#
# En este taller revisaremos las operaciones que nos ofrece **pandas** para crear
# nuevas columnas a partir de fórmulas en python.

# %%
# Vamos a seguir trabajando con el archivo de personas, así que en esta celda
# Importar Pandas y guarda en la variable df el archivo Excel
# ubicado en: https://github.com/luiscobo/poo/raw/refs/heads/main/Personas.xlsx

# %%
# Agregue una nueva columna
# "Altura en Metros" que resulte de la división de la Talla por 100 (Personas[Talla]/100).
# Muestre los primeros 5 elementos de la columna nueva

# %%
# Agregue una nueva columna que se llame "Altura al Cuadrado" que resulta de
# elevar al cuadrado de la columna "Altura en Metros".
# Muestre los primeros 5 elementos de la columna nueva

# %%
# Ahora agregue una nueva columna que se denomine "IMC" que es el resultado
# de la división del Peso y la Altura al Cuadrado.
# Muestre los primeros 5 elementos de la columna nueva

# %%
# Agregue una nueva columna que se llame "Aporte a la salud", la cual se calcula
# obteniendo el 12% de los ingresos (multiplique la columna Ingresos por 0.12).
# Muestre los primeros 5 elementos de la columna nueva

# %%
# Agregue una nueva columna que se llame "Aporte a Pensiones", la cual corresponde
# al 16% de los  Ingresos. Muestre los primeros 5 elementos de la columna nueva

# %%
# Agregue una nueva columna que se llame Salario Neto, la que se calcula restando
# de los Ingresos el "Aporte a la salud" y el "Aporte a Pensiones".
# Muestre los primeros 5 elementos de la columna nueva

# %%
# Agregue una columna llamada "Año nacimiento" que resulta de restar el
# año actual 2026 de la edad de la persona.
# Muestre los primeros 5 elementos de la columna nueva

# %% [markdown]
# ---
# Agregue una columna condicional llamada `Es Padre`, que tendrá el valor `NO` cuando la persona tenga 0 hijos y tendrá el valor `SI` de lo contrario. Muestre el valor de las primeras 5 filas de la nueva columna.

# %%
# Escriba el código aquí.

# %% [markdown]
# ---
# Agregue una columna condicional que se llama `Tiene Educación Universitaria`, el que tendrá el valor `SI` cuando el `Nivel Educativo` es `PREGRADO` o cuando es `POSTGRADO`. Tendrá el valor `NO` de lo contrario.

# %%
# Escriba el código aquí

# %% [markdown]
# ---
# Agregue una columna condicional que se llame `Categoría Salarial` el cual tendrá alguno de los siguientes valores:
#    * `BÁSICO` cuando los ingresos sean inferiores al millón de pesos.
#    * `JUNIOR` cuando los ingresos sean inferiores a los dos millones de pesos
#    * `SOFOMORO` cuando los ingresos sean inferiores a los tres millones de pesos.
#    * `SENIOR` de lo contrario.

# %%
# Escriba el código aquí

# %% [markdown]
# ---
# Agregue una nueva columna condicional que se llame `Clasificación IMC`, la cual posee uno de los siguientes valores:
#    * `DELGADEZ` si el índice de masa corporal es inferior a 18.5
#    * `NORMAL` si el índice de masa corporal es inferior a a 25
#    * `SOBREPESO` cuando el índice de masa corporal es inferior a 30.
#    * `OBESIDAD`  de lo contrario.

# %%
# Escriba el código aquí

# %% [markdown]
# ---
# * Agregue una nueva columna condicional que calcule el impuesto que debe pagar la persona. Esta nueva columna se llamará `Impuesto` y se calcula de acuerdo a la siguiente regla:
#     1. Si la persona es de estrato 2, el impuesto es el 4% (4% se escribe `0.04` )
#     2. Si la persona es de estrato 3, el impuesto es del 8%.
#     3. De lo contrario, el impuesto es del 12%.

# %%
# Escriba el código aquí

# %% [markdown]
# ---
# Agregue una columna personalizada que calcule el valor del impuesto, llámela así `Valor Impuesto` y se calcula a partir de la multiplicación del `Impuesto` por los `Ingresos`

# %%
# Escribir el código aquí

# %% [markdown]
# ---
# Agregue una columna personalizada que calcule la ayuda a discapacitados que se le da a la persona; esta nueva columna se llamará Ayuda Discapacitados y se calcula de la siguiente forma: si la persona usa lentes (`[Usa Lentes] = "SI"`) el resultado deberá ser la mitad de los ingresos (`[Ingresos]/2`) y un cero de lo contrario.

# %%
# Escribir el código aquí

# %% [markdown]
# ---
# Agregue una columna personalizada que se llame `Ayuda a Madres`, que se calcula de la siguiente manera: si la persona es mujer y tiene hijos, el valor es igual a la cuarta parte de los Ingresos; de lo contrario, el valor de la columna es cero.

# %%
# Escribir el código aquí

# %% [markdown]
# ---
# Agregue una columna personalizada que se llame `Ayuda a Futuros Propietarios`.  Para calcular el valor de esta columna se hará de la siguiente forma: si la persona no tiene casa y la persona no tiene automóvil, el resultado será los `[Ingresos] por 1.5`, en caso contrario el valor será de cero.

# %%
# Escribir el código aquí

# %% [markdown]
# Agregue una columna personalizada que se llame Ayuda a Ancianos. Para calcular el valor de esta columna se debe hacer de la siguiente forma: si la persona es una mujer y con más de 50 años de edad, el valor es el 5% de los ingresos (`[Ingresos] * 0.05`); si la persona es un hombre de más de 50 años, el valor de la columna es del 4% de los ingresos  (`[Ingresos] * 0.04`) ; de lo contrario, el valor de la columna sería cero.

# %%
# Escribir el código aquí
